        0.00012988,  0.00012834,  0.00012787,  0.00012725,  0.00012534,
        0.00011989,  0.00011973,  0.00011814,  0.00011811,  0.00011773,
        0.0001177 ,  0.00011736,  0.00011638,  0.00011634,  0.00011464,
        0.0001141 ,  0.00011407,  0.00011217,  0.00010723,  0.00010694,
        0.00010561,  0.00010297,  0.00010249,  0.00010057,  0.00010048])), 3: ([125, 3165, 1324, 47, 146535, 18725, 134269, 112129, 7958, 208994, 147030, 181189, 20079, 9356, 212916, 209076, 92598, 18352, 1008, 129819, 46609, 124468, 223867, 223710, 525428, 3018, 122692, 126123, 136445, 130120, 28671, 36994, 168368, 229976, 124620, 31391, 3147, 158109, 8335, 129220, 371, 33579, 219723, 7988, 5899, 359712, 140456, 4763, 214, 4239], np.array([ 0.00227743,  0.00038775,  0.00038325,  0.00034675,  0.0003162 ,
        0.00023782,  0.00023218,  0.00023191,  0.00019317,  0.00017859,
        0.00017593,  0.00017317,  0.00017179,  0.00017038,  0.00016728,
        0.00016671,  0.00016117,  0.00016087,  0.00015661,  0.00015086,
        0.00014784,  0.00014756,  0.0001469 ,  0.00014288,  0.00014155,
        0.0001362 ,  0.00013526,  0.00013363,  0.00013321,  0.00013168,
        0.00013136,  0.0001307 ,  0.00012873,  0.00012721,  0.00012675,
        0.00012636,  0.00012402,  0.00012293,  0.00012283,  0.00012207,
        0.00011775,  0.00011663,  0.00011455,  0.00011441,  0.00011437,
        0.00011405,  0.00011405,  0.00011328,  0.00011327,  0.0001113 ]))}}

# %%
len(d)
# Out:
# 2

# %%
def chart():
    a = np.ones(10)
    b = np.ones(12)
    b.fill(3)
    d = [0, 0.8, 0.92]

    f1 = plt.figure(1)
    plt.plot(a*2)
    plt.plot(d)
    plt.plot(d+d)

    plt.show()

# %%
chart
# Out:
# <function __main__.chart>

# %%
chart()

# %%
chart()

# %%
test = {81: [81], 90: [50], 101: [67]}
test2 = {81: [30], 40: [20], 200: [23]}
# repackage data into array-like for matplotlib 
# (see a preferred pythonic way below)
data = {"x":[], "y":[], "label":[]}
for label, coord in test.items():
    data["x"].append(label)
    data["y"].append(coord[0])
    data["label"].append(label)
data2 = {"x":[], "y":[], "label":[]}
for label, coord in test2.items():
    data2["x"].append(label)
    data2["y"].append(coord[0])
    data2["label"].append(label)
    
# display scatter plot data
plt.figure(figsize=(10,8))
plt.title('Scatter Plot', fontsize=20)
plt.xlabel('x', fontsize=15)
plt.ylabel('y', fontsize=15)
plt.plot(data["x"], data["y"], marker = 'o')
plt.plot(data2["x"], data2["y"], marker = 'o')
# add labels
#for label, x, y in zip(data["label"], data["x"], data["y"]):
#    plt.annotate(label, xy = (x, y))
